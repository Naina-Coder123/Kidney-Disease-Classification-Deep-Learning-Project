# %%
#configBox
d={"key":"val","key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2=ConfigBox({"key":"val","key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
#ensure_annotations
def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(x=2,y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(x=2,y=3)
# Out:
# 6

# %%
get_product(x=2,y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 get_product(x=2,y="3")
#
# File d:\Anaconda\envs\kidney\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000015CE20256C0> does not match annotation type <class 'int'>

# %% [markdown]
# ### download data from gdrive

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1DgIOoav6Ci2iN_bWOEK1V8VdQeRbN636/view?usp=drive_link"

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1DgIOoav6Ci2iN_bWOEK1V8VdQeRbN636'

# %%
prefix = f"https://drive.google.com/uc?id={file_id}"

gdown.download(prefix, "Kidney-CT-Scan-data.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1DgIOoav6Ci2iN_bWOEK1V8VdQeRbN636
# From (redirected): https://drive.google.com/uc?id=1DgIOoav6Ci2iN_bWOEK1V8VdQeRbN636&confirm=t&uuid=a923cb7f-aefd-45e4-8238-dde0c7c74bbb
# To: c:\Users\naina\Kidney-Disease-Classification-Deep-Learning-Project\research\Kidney-CT-Scan-data.zip
# 100%|██████████| 1.63G/1.63G [07:47<00:00, 3.48MB/s]
# 'Kidney-CT-Scan-data.zip'
